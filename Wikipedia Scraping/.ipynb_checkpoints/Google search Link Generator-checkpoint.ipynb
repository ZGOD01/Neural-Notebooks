# %%
import requests
from bs4 import BeautifulSoup

# %%
title = str(input('Enter the Topic: ')).replace(' ' , "+")

link = 'https://www.google.com/search?q=' + title + '+wikipedia'
# Out:
# Enter the Topic:  Jonathan Gaming

# %%
res = requests.get(link)
soup = BeautifulSoup(res.text , 'html.parser')

# %%
for sp in soup.find_all('div'):
    try:
        link = sp.find('a').get('href')  
        if 'en.wikipedia.org' in link:
            break
    except:
        pass

link = "https://google.com" + link.split('&')[0]

# %%
link
# Out:
# 'https://google.com/search?q=Jonathan+Gaming+wikipedia'
